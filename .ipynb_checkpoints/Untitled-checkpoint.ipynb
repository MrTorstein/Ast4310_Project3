# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2 * np.pi, 1000)
r = (np.sin(theta) / (1 - beta * np.cos(theta)) ** 5) ** 2
x = r * np.cos(theta)
y = r * np.sin(theta)

plt.plot(x,y)

#dP / dOmg = np.sin(theta) / (1 - beta * cos(theta)) ** 5
#Omega = np.linspace(-2, 2, 50)
#P = 0
#for i in range(len(Omega) - 1):
#    P[i + 1] = P[i] + np.sin(theta) / (1 - beta * cos(theta)) ** 5 * (Omega[-1] - Omega[0] / len(Omega))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-368359292ae8> in <module>
#      14 P = 0
#      15 for i in range(len(Omega) - 1):
# ---> 16     P[i + 1] = P[i] + np.sin(theta) / (1 - beta * cos(theta)) ** 5 * (Omega[-1] - Omega[0] / len(Omega))
#
# TypeError: 'int' object is not subscriptable
