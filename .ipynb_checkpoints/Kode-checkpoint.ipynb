# %%
# %%javascript  # Allow equation numbers
# MathJax.Hub.Config({
#     TeX: { equationNumbers: { autoNumber: "AMS" } }
# });

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from astropy import units
from astropy import constants
from astropy.table import QTable  # to use tables with units
from astropy.visualization import quantity_support
from IPython.display import set_matplotlib_formats

from astropy.modeling.models import BlackBody
from astropy.modeling.blackbody import blackbody_lambda
from astropy.modeling.blackbody import blackbody_nu

quantity_support()
set_matplotlib_formats('svg')
plt.rc('legend', frameon=False)
#plt.rc('figure', figsize=(10, 8)) # Larger figure sizes

# %% [markdown]
# Vi har at I=B, så vi finner brightness temp ved å si at B=I og så henter vi ut bølgelengde og frekvens fra observasjoner og løser for T.

# %%
# Define variables:
e = constants.e
c = constants.c
m_e = constants.m_e
k_B = constants.k_B
h = constants.h
g_ = 2.499      #effective Landé factor


# Read observations from data set:
data = QTable.read('SST_sunspot_617_2020.08.07.fits')
Stokes_V = data["stokes_v"]
I = data["intensity"]
lam = data["wavelength"]           #observed Doppler-shifted wavelength
lam0 = 617.300 * units.nm          #rest wavelength
#I_lam = #?                        #intensiteten ved lambda0


# Functions: 
def T_b(lam, I): #brightness temperature
    T_brightness = 1 / (np.log((2*h*(c**2))/(lam**5 * I) + 1) * (lam*k_B / h*c))
    return units.Quantity(T_brightness, unit='K')

#print("Brightness temperature T_b: ",T_b(lam0, I)) #FUNKER IKKE

def Doppler_effect(lam0, lam):
    v = constants.c * ((lam0 - lam)/lam0) #velocity of the body
    return v

def mu_func(): #cos(theta), the actual velocity we observes
    return 8   #TEMPORARY
    
def line_of_sight_vel(v,mu):
    v_los = v*mu
    return v_los

print("Velocity affected by the Doppler effect: ", Doppler_effect(lam0, lam))
print("The line of sight velocity:", line_of_sight_vel(Doppler_effect(lam0,lam),mu_func()))


def Zeeman_effect(lam0, B):
    delta_lamb = (e / (4*np.pi*m_e*c)) * lam0**2 * B
    return delta_lamb


#def dI_dlam():
#    di_dl = intensity[i] #? vente litt med denne?
#    return di_dl

#def B_los(lam, lam0):
#    for i in range(len(lam)):
#        sum1 = dI_dlam[i]*Stokes_V[i]
#        sum2 = dI_dlam[i]**2
#    return -(4*np.pi*m_e*c)/(e*g_*lam0**2) * (sum1/sum2)


def I_inv(I):
    return I[0] - I 

def FWHM():
    #sigma = #?
    return 2*np.sqrt(2*np.log(2*sigma))
# Out:
# Velocity affected by Doppler effect:  [ 15540.83696092  11655.62772072   7770.41848046   5827.81386033
#    3885.2092402    1942.60462007      0.          -1942.60462013
#   -3885.20924026  -5827.81386039  -7770.41848052 -11655.62772072
#  -15540.83696098] m / s
# The line of sight velocity: [ 124326.69568738   93245.02176576   62163.34784369   46622.51088266
#    31081.67392162   15540.83696059       0.          -15540.83696103
#   -31081.67392207  -46622.5108831   -62163.34784413  -93245.02176576
#  -124326.69568782] m / s

# %%
# Plot:
fig, ax = plt.subplots(figsize=(7,7))
ax.imshow(data['intensity'][0].value, vmax=4.6e-8, cmap='inferno');

cbar_ax = fig.add_axes([0.02, 0.1/5, 0.02, 0.85])
cbar_ax.tick_params(labelsize=10)

#cbar = fig.colorbar(im1, cax=cbar_ax) #NOE FEIL PÅ DE?
#cbar.set_label("Intensity",size=18)

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.imshow(data['stokes_v'][4].value,  cmap='gist_gray');
cbar_ax = fig.add_axes([0.05, 0.1/5, 0.02, 0.85])
cbar_ax.tick_params(labelsize=10)

# %%
fig, ax = plt.subplots(figsize=(6, 4))
wavelength = data['wavelength']
ax.plot(wavelength, data['intensity'][:, 200, 200], label='Granulation')
ax.plot(wavelength, data['intensity'][:, 400, 550], label='Umbra')
ax.legend();
