# %%
import numpy as np
import matplotlib.pyplot as plt

beta = 0.9

theta = np.linspace(0, 2 * np.pi, 1000)
r = np.sin(theta) ** 2 / (1 - beta * np.cos(theta)) ** 5
x = r * np.cos(theta)
y = r * np.sin(theta)

plt.plot(x,y)
